# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/customer-segmentation-tutorial-in-python/Mall_Customers.csv

# %% [markdown]
# #### Import Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv('/kaggle/input/customer-segmentation-tutorial-in-python/Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
## Statistical info
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
## Datatype info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.distplot(df['Age'])

# %%
sns.distplot(df['Annual Income (k$)'])

# %%
sns.distplot(df['Spending Score (1-100)'])

# %% [markdown]
# ## Correlation Matrix

# %%
corr = df.select_dtypes(include=['number']).corr()
sns.heatmap(corr,annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
## Cluster on 2 features
df1 = df[['Annual Income (k$)','Spending Score (1-100)']]
df1.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
## Scatter plot
sns.scatterplot(x = df1['Annual Income (k$)'],y = df1['Spending Score (1-100)'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
from sklearn.cluster import KMeans
errors = []
for i in range (1, 11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df1)
    errors.append(kmeans.inertia_)

# %%
# Plot the results for elbow method
plt.figure(figsize=(13,6))
plt.plot(range(1,11),errors)
plt.plot(range(1,11),errors, linewidth = 3, color = 'red',marker ='8')
plt.xlabel('No. of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
km = KMeans(n_clusters=5)
km.fit(df1)
y=km.predict(df1)
df1['Label']= y
df1.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Label
# 0                  15                      39      4
# 1                  15                      81      3
# 2                  16                       6      4
# 3                  16                      77      3
# 4                  17                      40      4

# %%
sns.scatterplot(x='Annual Income (k$)',y = 'Spending Score (1-100)', data = df1, hue = 'Label',s=50,palette = ['red','green','brown','blue','orange'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
# Cluster on 3 features
df2 = df[['Annual Income (k$)','Spending Score (1-100)','Age']]
df2.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Age
# 0                  15                      39   19
# 1                  15                      81   21
# 2                  16                       6   20
# 3                  16                      77   23
# 4                  17                      40   31

# %%
errors = []
for i in range (1, 11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df1)
    errors.append(kmeans.inertia_)

# %%
# Plot the results for elbow method
plt.figure(figsize=(13,6))
plt.plot(range(1,11),errors)
plt.plot(range(1,11),errors, linewidth = 3, color = 'red',marker ='8')
plt.xlabel('No. of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
km = KMeans(n_clusters=5)
km.fit(df2)
y=km.predict(df2)
df2['Label']= y
df2.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Age  Label
# 0                  15                      39   19      0
# 1                  15                      81   21      2
# 2                  16                       6   20      0
# 3                  16                      77   23      2
# 4                  17                      40   31      0

# %%
## 3d scatterplot
fig = plt.figure(figsize=(20,20))
ax= fig.add_subplot(111,projection='3d')

ax.scatter(df2['Age'][df2['Label']==0],df2['Annual Income (k$)'][df2['Label']==0],df2['Spending Score (1-100)'][df2['Label']==0],c='red',s=50)
ax.scatter(df2['Age'][df2['Label']==1],df2['Annual Income (k$)'][df2['Label']==1],df2['Spending Score (1-100)'][df2['Label']==1],c='green',s=50)
ax.scatter(df2['Age'][df2['Label']==2],df2['Annual Income (k$)'][df2['Label']==2],df2['Spending Score (1-100)'][df2['Label']==2],c='blue',s=50)
ax.scatter(df2['Age'][df2['Label']==3],df2['Annual Income (k$)'][df2['Label']==3],df2['Spending Score (1-100)'][df2['Label']==3],c='brown',s=50)
ax.scatter(df2['Age'][df2['Label']==4],df2['Annual Income (k$)'][df2['Label']==4],df2['Spending Score (1-100)'][df2['Label']==4],c='orange',s=50)   
ax.view_init(30,190)
ax.set_xlabel('Age')
ax.set_ylabel('Annual Income')           
ax.set_zlabel('Spending Score') 
plt.show()

# %%
## My interpretation based on grouping by label
df2.groupby('Label').mean()
# Out:
#        Annual Income (k$)  Spending Score (1-100)        Age
# Label
# 0               26.304348               20.913043  45.217391
# 1               87.750000               17.583333  40.666667
# 2               26.304348               78.565217  25.521739
# 3               55.291139               49.569620  43.088608
# 4               86.538462               82.128205  32.692308

# %%
## Here is the final interpretation
# Label 0 - Mid-age adults with low income and very low spending — highly budget-conscious.
# Label 1 - High-income individuals who spend very little — likely prefer saving/investing over splurging.
# Label 2 - Young adults with modest income but very high spending — impulse-driven shoppers.
# Label 3 - Average income and spending — balanced lifestyle, neither frugal nor extravagant.
# Label 4 - High-income, young-to-mid-age shoppers with very high spending — luxury-oriented buyers.

## So accordingly we can taget these customers with relevant offers
